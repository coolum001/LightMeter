# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import dates

import seaborn as sns

# %%
data = pd.read_csv('/ArduinoLogging/2020-05-07-085450.csv',  names=['Time', 'Light'], )
data.head()
# Out:
#                           Time  Light
# 0  2020-05-07 08:54:58.881301    1002
# 1  2020-05-07 08:54:59.044287    1002
# 2  2020-05-07 08:54:59.209290    1002
# 3  2020-05-07 08:55:00.027234    1002
# 4  2020-05-07 08:55:00.876184    1002

# %%
data.dtypes
# Out:
# Time     object
# Light     int64
# dtype: object

# %%
data['Time'] = pd.to_datetime(data['Time'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
data.dtypes
# Out:
# Time     datetime64[ns]
# Light             int64
# dtype: object

# %%
data.head()
# Out:
#                         Time  Light
# 0 2020-05-07 08:54:58.881301   1002
# 1 2020-05-07 08:54:59.044287   1002
# 2 2020-05-07 08:54:59.209290   1002
# 3 2020-05-07 08:55:00.027234   1002
# 4 2020-05-07 08:55:00.876184   1002

# %%
data.plot('Time', 'Light', )

# %%
fig, ax = plt.subplots( figsize=(12,10))
data.plot('Time', 'Light', ax=ax)

# %%
fig, ax = plt.subplots( figsize=(10,8))

# just show hour minute in x axis labels
hfmt = dates.DateFormatter('%H:%M')

# we just want ticks and labels at every hour
ax.xaxis.set_major_locator(dates.HourLocator())
ax.xaxis.set_major_formatter(hfmt)

ax.set_xlabel('Time of Day')
ax.set_ylabel('Light Sensor Reading')

ax.set_title('Light Sensor Values', fontsize=40, )
ax.plot(data['Time'], data['Light'], label='Light Level',)

# create a grid and a legend at lower left
ax.legend(loc='lower left')
ax.grid(axis='both', which='major',)

# autofmt is OK but prefer x axis labels vertical
#fig.autofmt_xdate()

# prefer the x axis labels to be vertical
ax.tick_params(axis='x', labelrotation= 90)

# %%
len(data)
# Out:
# 84976

# %%
fig, ax = plt.subplots( figsize=(10,8))

sns.lineplot('Time', 'Light', data=data, ax=ax,)
